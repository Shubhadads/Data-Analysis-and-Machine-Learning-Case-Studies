# %% [markdown]
# #Problem Statement
#
# About Fitbit
#
# Fitbit is a leading brand in the field of fitness equipment. Fitbit provides a product range including machines such as treadmills, exercise bikes, gym equipment, and fitness accessories to cater to the needs of all categories of people.
#
#
# Business Problem
#
# The market research team at Fitbit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.
#
# Perform descriptive analytics to create a customer profile for each Fitbit treadmill product by developing appropriate tables and charts.
# For each Fitbit treadmill product, construct two-way contingency tables and compute all conditional and marginal probabilities along with their insights/impact on the business.
# Dataset
#
# The company collected the data on individuals who purchased a treadmill from the Fitbit stores during the prior three months. The dataset has the following features:
#
# Dataset link: Fitbit_treadmill.csv
#
# Product Purchased:	KP281, KP481, or KP781
# Age:	In years
# Gender:	Male/Female
# Education:	In years
# MaritalStatus:	Single or partnered
# Usage:	The average number of times the customer plans to use the treadmill each week.
# Income:	Annual income (in $)
# Fitness:	Self-rated fitness on a 1-to-5 scale, where 1 is the poor shape and 5 is the excellent shape.
# Miles:	The average number of miles the customer expects to walk/run each week
# Product Portfolio:
#
# The KP281 is an entry-level treadmill that sells for $1,500.
# The KP481 is for mid-level runners that sell for $1,750.
# The KP781 treadmill is having advanced features that sell for $2,500.

# %% [markdown]
# What good looks like?
#
# Import the dataset and do usual data analysis steps like checking the structure & characteristics of the dataset
# Detect Outliers (using boxplot, “describe” method by checking the difference between mean and median)
# Check if features like marital status, age have any effect on the product purchased (using countplot, histplots, boxplots etc)
# Representing the marginal probability like - what percent of customers have purchased KP281, KP481, or KP781 in a table (can use pandas.crosstab here)
# Check correlation among different factors using heat maps or pair plots.
# With all the above steps you can answer questions like: What is the probability of a male customer buying a KP781 treadmill?
# Customer Profiling - Categorization of users.
# Probability- marginal, conditional probability.
# Some recommendations and actionable insights, based on the inferences.
# Later on, we will see more ways to do “customer segmentation”, but this case study in itself is relevant in some real-world scenarios.

# %%
import pandas as pd
import numpy as np

# %%
Fitbit=pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/Fitbit_treadmill.csv?1639992749")

# %%
Fitbit.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
Fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# # Insights
#
# The data is clean will attributes having all non-null values, also the parameters are in correct data format.
# Those attributes with object datatype may be converted to string later for analysis
# The data has 180 rows and 9 attributes

# %%
Fitbit.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# # Insights -
#
# this function shows the most frequently occuring values for non numeric attributes (categorical), and mean, median comparison can be done for numeric attributes.
#
# we see that -
# 1. there are 3 unique products, with KP281 selling the most
# 2. more than 50% of customers who use treadmill are 'Partnered' and remaining are single
# 3. Most of the customers (50%) who use treadmills are 'Male' and remaining female
#
# The difference between mean and median can be considered as the basis for selecting attributes for outlier analysis.
#
# Here we see that, the mean and median for miles column have considerable difference and this can be mainly analyzed for outliers, along with other parameters such as age, education, usage, fitness and income

# %% [markdown]
# # Non graphical analysis
#
# continued
# In this section we check value counts and unique values of categorical attributes and check distribution of customers across age, education and income

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# a plot to show Genderwise distribution of customers
sns.countplot(data=Fitbit,x='Gender')
plt.title("Genderwise distribution of customers")
plt.show()

# %%
# a plot to show treadmill wise distribution of customers
sns.countplot(data=Fitbit,x='Product')
plt.title("Product wise distribution of customers")
plt.show()

# %%
#Univariate analysis

fig=plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
sns.histplot(data=Fitbit,
 x="Age", kde=True)
plt.title("Distribution of customers - Agewise")

plt.subplot(2,2,2)
sns.histplot(data=Fitbit,
 x="Education", kde=True)
plt.title("Distribution of customers - Eductaion wise")

plt.subplot(2,2,3)
sns.histplot(data=Fitbit,
 x="Income", kde=True)
plt.title("Distribution of customers - Income wise")

plt.subplot(2,2,4)
sns.histplot(data=Fitbit,
 x="Fitness", kde=True)
plt.title("Distribution of customers - Fitness wise")

fig.suptitle("Univariate analysis wrt different attributes")
plt.show()

# %% [markdown]
# #Insights
#
# 1. Most of the customers lie in age group of 20 to 30 years age, whereas there are customers across range of 20-50 years.
# 2. Most of the customers for treadmill are those who have completed 14, 16 or 18 years of education and range goes from 12 -20 years of education
# 3. only those customers who have income greater than 30000 dollars buy treadmill and income of most of the customers who buy treadmill falls in the range of 30k - 70k dollars, The higest income for customer is 100000 dollars.
# 4. Most of the customers for treadmill are those who feel that they have medium 3 rating of fitness.

# %% [markdown]
# #Bivariate Analysis
#
# To perform this we use pairplot

# %%
sns.pairplot(data=Fitbit, hue='Product')

# %% [markdown]
# #Insights and recommendations
#
# From above analysis we see following relationships
#
# KDE plots
# 1. customer distribution across education shows that those who are highly educated prefer KP781
# 2. customer distribution across usage shows that those who plan for high usage rate prefer KP781
# 3.customer distribution across fitness and miles shows that those who rate themselves high in fitness and commit to more miles prefer KP781
# 4. The distribution of customers has two peaks one at 50k and 100k income levels
#
# **Overall we can say that those people who are highly educated (16 or 18 years) and those who have high fitness perception (5 rating) and planned usage rate more than 3 times per week, having income >=50k plan to commit to more miles and tend to buy the high end KP781 treadmill - These are the target customers for KP781**
#
# **Bivariate insights**
#
# 1. Age-Income - we see that most customers belong to 20-35 age bracket and 30k-60k income bracket, these are the overall customers of treadmill.
#
# **high income customers >70k dollars buy KP781 irrespective of their age group**
#
# 2. Age-miles: only those customers who buy KP781 tend to plan a walk for higher number of miles compared to others, across all age groups.
#
# 3.Income-miles: This graph also clearly shows that those with higher levels of income plan to walk more number of miles per week

# %% [markdown]
# # Outlier detection
#
# We will do this for numeric attributes

# %%
plt.figure(figsize=(16,12))

plt.subplot(2,3,1)
sns.boxplot(data=Fitbit,y='Miles')
plt.title("outlier customer Miles")

plt.subplot(2,3,2)
sns.boxplot(data=Fitbit,y='Miles',x='MaritalStatus')
plt.title("Outlier customer Miles wrt Marital Status")

plt.subplot(2,3,3)
sns.boxplot(data=Fitbit,y='Miles',x='Gender')
plt.title("outlier customer Miles wrt Gender")

plt.subplot(2,3,4)
sns.boxplot(data=Fitbit,y='Income')
plt.title("outlier customer incomes")

plt.subplot(2,3,5)
sns.boxplot(data=Fitbit,y='Income',x='MaritalStatus')
plt.title("Outlier customer incomes wrt Marital Status")

plt.subplot(2,3,6)
sns.boxplot(data=Fitbit,y='Income',x='Gender')
plt.title("outlier customer incomes wrt Gender")

plt.show()

# %% [markdown]
# #Insights
#
# 1. Th miles outliers lie above 170 miles/week. It can be seen that the minimum to maximum range of partenered is much higher than single however the median miles/week for single customers id higher than partenered customers. The male customers plan more miles/week than female customers and their outliers also lie above 200 miles/week whereas for female customers the outliers lie above 140 miles/week
#
# 2. Income outliers lie above 78-70k dollars. The median incomes are single/partnered are almost similar, same follows for genders. However the outliers and IQR is greater in Partnered and male customers.

# %%
plt.figure(figsize=(16,12))
plt.subplot(2,3,1)
sns.boxplot(data=Fitbit,y='Age')
plt.title("outlier customer Age")

plt.subplot(2,3,2)
sns.boxplot(data=Fitbit,y='Age',x='MaritalStatus')
plt.title("Outlier customer Age wrt Marital Status")

plt.subplot(2,3,3)
sns.boxplot(data=Fitbit,y='Age',x='Gender')
plt.title("outlier customer Age wrt Gender")

plt.subplot(2,3,4)
sns.boxplot(data=Fitbit,y='Education')
plt.title("outlier customer Education")

plt.subplot(2,3,5)
sns.boxplot(data=Fitbit,y='Education',x='MaritalStatus')
plt.title("Outlier customer Education wrt Marital Status")

plt.subplot(2,3,6)
sns.boxplot(data=Fitbit,y='Education',x='Gender')
plt.title("outlier customer Education wrt Gender")

plt.show()

# %% [markdown]
# # Insights
#
# 1.Those above 45 years of age are outliers. here also the IQR and outliers are more in partnered customers and male customers compared to other counterpart.
#
# 2.Outliers in education are those who took education for more than 18 years.

# %%
#pd.pivot_table(Fitbit,columns=['Gender','MaritalStatus','Product'],index=['Age'],
#             values='Usage',aggfunc='count',
#             margins=True)

# %%
#probabilty
pd.crosstab(Fitbit.Product,Fitbit.Gender,
            margins=True,normalize=True).round(2)
# Out:
# Gender   Female  Male   All
# Product
# KP281      0.22  0.22  0.44
# KP481      0.16  0.17  0.33
# KP781      0.04  0.18  0.22
# All        0.42  0.58  1.00

# %%
#Count
pd.crosstab(Fitbit.Product,Fitbit.Gender,
            margins=True,normalize=False).round(2)
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %% [markdown]
# # Probability
#
# Marginal probability of customer buying each of the three products is given by vertical margin values in probability table.
#
#
# **Marginal Probability of customers buying particular treadmill**
#
# KP281 - 44%
#
# KP481 - 33%
#
# KP781 - 22%
#
# **Conditional Probability of buying each of the treadmill products given that customer is a 'Female'**
#
# KP281 - 40/76 = 52.6%
#
# KP481 - 29/76 = 38.1%
#
# KP781 - 7/76 = 9.2%
#
# **Conditional Probability of buying each of the treadmill products given that  customer is a 'Male'**
#
# KP281 - 40/104 = 38.4%
#
# KP481 - 31/104 = 29.8%
#
# KP781 - 33/104 = 31.7%
#
# **Marginal probability of female buying treadmill** = 76/180 = 42.2%
#
# **Marginal probability of male buying treadmill** = 104/180 =57.7%
#
#
# --Preferred products based on gender (conditional prob.) -
# These are top preferences based on gender for particular product
#
# KP281 - female - 52% (52% females prefer KP281 treadmill)
#
# KP481 - female - 38%
#
# KP781 - male - 31%
#
# --Target customers based on gender and marginal prob. of total sales for each product
#
# KP281 - female and male - 22%
#
# KP481 - female - 16% and male - 17%
#
# KP781 - male - 18%
#
# Recommendations:
# where 52% females prefer to buy KP281 treadmill, the female customer base is only 42%, so in terms of total sales,the target customers become both males and females.

# %%
# This table gives marginal probabilities
pd.crosstab(Fitbit.Product,[Fitbit.Gender,Fitbit.MaritalStatus],
            margins=True,normalize=True).round(2)
# Out:
# Gender           Female             Male          All
# MaritalStatus Partnered Single Partnered Single
# Product
# KP281              0.15   0.07      0.12   0.11  0.44
# KP481              0.08   0.08      0.12   0.06  0.33
# KP781              0.02   0.02      0.11   0.08  0.22
# All                0.26   0.17      0.34   0.24  1.00

# %%
pd.crosstab(Fitbit.Product,[Fitbit.Gender,Fitbit.MaritalStatus],
            margins=True,normalize=False).round(2)
# Out:
# Gender           Female             Male         All
# MaritalStatus Partnered Single Partnered Single
# Product
# KP281                27     13        21     19   80
# KP481                15     14        21     10   60
# KP781                 4      3        19     14   40
# All                  46     30        61     43  180

# %% [markdown]
# **Probabilities**
#
# 1. Horizontal margin gives marginal probabilities of partenered and single, male and female customers buying treadmill.
# --This shows that partnered male 34% and female 26% are main customers for treadmills
#
# 2. Target customers for each product based on marginal probability
#
# KP281 - partnered female - 15%
#
# KP481 - partnered male - 12%
#
# KP781 - partnered male - 11%

# %%
a=Fitbit.copy(deep=True)

# %%
a['age_group'] = pd.qcut(a['Age'],
                              q=5)
a.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   KP281   18    Male         14        Single      3        4   29562
# 1   KP281   19    Male         15        Single      2        3   31836
# 2   KP281   19  Female         14     Partnered      4        3   30699
# 3   KP281   19    Male         12        Single      3        3   32973
# 4   KP281   20    Male         13     Partnered      4        2   35247
#
#    Miles       age_group
# 0    112  (17.999, 23.0]
# 1     75  (17.999, 23.0]
# 2     66  (17.999, 23.0]
# 3     85  (17.999, 23.0]
# 4     47  (17.999, 23.0]

# %%
a['age_group'].unique()
# Out:
# [(17.999, 23.0], (23.0, 25.0], (25.0, 29.0], (29.0, 34.2], (34.2, 50.0]]
# Categories (5, interval[float64, right]): [(17.999, 23.0] < (23.0, 25.0] < (25.0, 29.0] <
#                                            (29.0, 34.2] < (34.2, 50.0]]

# %%
#pd.crosstab(a.Product,[a.Gender,a.age_group],
#           margins=True,normalize=False).round(2).plot.bar(stacked=True)

# %%
#probability
pd.crosstab(a.Product,[a.Gender,a.age_group],
           margins=True,normalize=True).round(3)
# Out:
# Gender            Female                                                      \
# age_group (17.999, 23.0] (23.0, 25.0] (25.0, 29.0] (29.0, 34.2] (34.2, 50.0]
# Product
# KP281              0.056        0.039        0.061        0.028        0.039
# KP481              0.028        0.039        0.017        0.044        0.033
# KP781              0.006        0.011        0.011        0.011        0.000
# All                0.089        0.089        0.089        0.083        0.072
#
# Gender              Male                                                      \
# age_group (17.999, 23.0] (23.0, 25.0] (25.0, 29.0] (29.0, 34.2] (34.2, 50.0]
# Product
# KP281              0.067        0.028        0.044        0.028        0.056
# KP481              0.050        0.039        0.011        0.039        0.033
# KP781              0.028        0.050        0.044        0.022        0.039
# All                0.144        0.117        0.100        0.089        0.128
#
# Gender       All
# ...

# %%
#count
pd.crosstab(a.Product,[a.Gender,a.age_group],
           margins=True,normalize=False).round(2)
# Out:
# Gender            Female                                                      \
# age_group (17.999, 23.0] (23.0, 25.0] (25.0, 29.0] (29.0, 34.2] (34.2, 50.0]
# Product
# KP281                 10            7           11            5            7
# KP481                  5            7            3            8            6
# KP781                  1            2            2            2            0
# All                   16           16           16           15           13
#
# Gender              Male                                                      \
# age_group (17.999, 23.0] (23.0, 25.0] (25.0, 29.0] (29.0, 34.2] (34.2, 50.0]
# Product
# KP281                 12            5            8            5           10
# KP481                  9            7            2            7            6
# KP781                  5            9            8            4            7
# All                   26           21           18           16           23
#
# Gender     All
# ...

# %% [markdown]
# --Overall target customers for treadmill
#
# Males  - top age groups - 17-23,34-50,23-25
# females - not much difference in buying pattern across age
#
# -- target customers (top) for each product across genders and age
#
# KP281 - female - 18-23 age - 5.6%
#
#       - male - 18-23 age - 6.7%
#
# KP481 - female - 29-34 age - 4.4%
#
#       - male - 18-23 age - 5%
#
# KP781 - female - 29-34 age - 4.4%
#
#       - male - 23-25,25-29.34-50 age
#
# males in age group 17-23,34-50,24-25 buy more treadmills than those in remaining age groups. buying pattern for females is same across all age groups

# %%
pd.crosstab(a.Product,[a.MaritalStatus,a.age_group],
           margins=True,normalize=False).round(2)
# Out:
# MaritalStatus      Partnered                                         \
# age_group     (17.999, 23.0] (23.0, 25.0] (25.0, 29.0] (29.0, 34.2]
# Product
# KP281                     10            7           14            4
# KP481                      9            6            2            9
# KP781                      0            8            6            5
# All                       19           21           22           18
#
# MaritalStatus                      Single                            \
# age_group     (34.2, 50.0] (17.999, 23.0] (23.0, 25.0] (25.0, 29.0]
# Product
# KP281                   13             12            5            5
# KP481                   10              5            8            3
# KP781                    4              6            3            4
# All                     27             23           16           12
#
# MaritalStatus                            All
# age_group     (29.0, 34.2] (34.2, 50.0]
# Product
# ...

# %% [markdown]
# -- Target customers for treadmills
#
# partnered customers in 34-50 age are top customers
#
# single customers in 18-23 are top customers
#
# any stark pattern is not seen in age group v/s marital status across products.

# %%
a['income_group'] = pd.qcut(a['Income'],
                              q=5)
a.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   KP281   18    Male         14        Single      3        4   29562
# 1   KP281   19    Male         15        Single      2        3   31836
# 2   KP281   19  Female         14     Partnered      4        3   30699
# 3   KP281   19    Male         12        Single      3        3   32973
# 4   KP281   20    Male         13     Partnered      4        2   35247
#
#    Miles       age_group          income_group
# 0    112  (17.999, 23.0]  (29561.999, 40932.0]
# 1     75  (17.999, 23.0]  (29561.999, 40932.0]
# 2     66  (17.999, 23.0]  (29561.999, 40932.0]
# 3     85  (17.999, 23.0]  (29561.999, 40932.0]
# 4     47  (17.999, 23.0]  (29561.999, 40932.0]

# %%
#We have seen correlation between income and age group in pair plot, we analyze the same
pd.crosstab([a.Product,a.income_group],a.age_group,
           margins=True,normalize=False).round(2)
# Out:
# age_group                     (17.999, 23.0]  (23.0, 25.0]  (25.0, 29.0]  \
# Product income_group
# KP281   (29561.999, 40932.0]              22             3             1
#         (40932.0, 47754.0]                 0             7             6
#         (47754.0, 52756.8]                 0             1             7
#         (52756.8, 61398.0]                 0             1             4
#         (61398.0, 104581.0]                0             0             1
# KP481   (29561.999, 40932.0]              10             1             0
#         (40932.0, 47754.0]                 4             8             2
#         (47754.0, 52756.8]                 0             5             3
#         (52756.8, 61398.0]                 0             0             0
#         (61398.0, 104581.0]                0             0             0
# KP781   (47754.0, 52756.8]                 3             3             1
# ...

# %%
pd.crosstab([a.Product,a.income_group],a.age_group,
           margins=True,normalize=True).round(3)
# Out:
# age_group                     (17.999, 23.0]  (23.0, 25.0]  (25.0, 29.0]  \
# Product income_group
# KP281   (29561.999, 40932.0]           0.122         0.017         0.006
#         (40932.0, 47754.0]             0.000         0.039         0.033
#         (47754.0, 52756.8]             0.000         0.006         0.039
#         (52756.8, 61398.0]             0.000         0.006         0.022
#         (61398.0, 104581.0]            0.000         0.000         0.006
# KP481   (29561.999, 40932.0]           0.056         0.006         0.000
#         (40932.0, 47754.0]             0.022         0.044         0.011
#         (47754.0, 52756.8]             0.000         0.028         0.017
#         (52756.8, 61398.0]             0.000         0.000         0.000
#         (61398.0, 104581.0]            0.000         0.000         0.000
# KP781   (47754.0, 52756.8]             0.017         0.017         0.006
# ...

# %% [markdown]
# --Target customers
#
# Here we see a stark pattern of customers for each product for age group v/s income group
#
# Top customers (Target) based on Marginal probability
#
# KP281 - age - 17-23 years, income 30k to 40.9k dollars
#
# KP481 - female - 17-23 years, income 30k to 40.9k dollars
#
# KP781 - 25-29 years, income 61.3k to 104.4k dollars
